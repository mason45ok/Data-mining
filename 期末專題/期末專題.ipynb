# %%
import google.generativeai as genai
import os
from dotenv import load_dotenv

# 載入 .env 文件中的環境變數
load_dotenv()

# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY = os.getenv('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
# for m in genai.list_models():
#   if 'generateContent' in m.supported_generation_methods:
#     print(m.name)

# %%
import re

def remove_mark(text):
    # 移除HTML標記
    text = re.sub(r'<[^>]+>', '', text)
    # text = text.replace('\n', '')
    text = text.replace(' ', '')
    text = text.replace('#', '')
    text = text.replace('*', '')
    text = text.replace('\n', '')
    return text

# %%
import textwrap
from IPython.display import Markdown
def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import PyPDF2
import os
import glob


def extract_text_from_pdfs_in_directory(directory):
    text = ""
    pdf_files = glob.glob(os.path.join(directory, "./*.pdf"))
    for pdf_file in pdf_files:
        with open(pdf_file, "rb") as f:
            reader = PyPDF2.PdfReader(f)
            num_pages = len(reader.pages)
            for page_num in range(num_pages):
                page = reader.pages[page_num]
                text += page.extract_text()
    return text

# 使用上述函數從 PDF 中提取文字
pdf_text = extract_text_from_pdfs_in_directory("C:/Users/mason/Desktop/作業/科技系/教育資料探勘專題製作/Data-mining/期末專題")
#For Debug
pdf_text
# Out:
# '岳陽樓記  范仲淹  \n  慶曆四年春 ，滕子京謫守巴陵郡 。越明年，政通人和 ，百廢具興 。乃重修\n岳陽樓，增其舊制 ，刻唐賢、今人詩賦於其上 ；屬予作文以記之 。 \n  予觀夫巴陵勝狀 ，在洞庭一湖 。銜遠山，吞長江，浩浩湯湯 ，橫無際涯 ；\n朝暉夕陰 ，氣象萬千 。此則岳陽樓之大觀也 ，前人之述備矣 。然則北通巫峽 ，\n南極瀟湘 ，遷客騷人 ，多會於此 ，覽物之情 ，得無異乎 ？ \n  若夫霪雨霏霏 ，連月不開 ；陰風怒號 ，濁浪排空 ；日星隱耀 ，山岳潛形 ；\n商旅不行 ，檣傾楫摧 ；薄暮冥冥 ，虎嘯猿啼 。登斯樓也 ，則有去國懷鄉 ，憂讒\n畏譏，滿目蕭然 ，感極而悲者矣 。 \n  至若春和景明 ，波瀾不驚 ，上下天光 ，一碧萬頃 ；沙鷗翔集 ，錦鱗游泳 ，\n岸芷汀蘭 ，郁郁青青 。而或長煙一空 ，皓月千里 ，浮光躍金 ，靜影沉璧 ；漁歌\n互答，此樂何極 ！登斯樓也 ，則有心曠神怡 ，寵辱皆忘 ，把酒臨風 ，其喜洋洋\n者矣。 \n  嗟夫！予嘗求古仁人之心 ，或異二者之為 。何哉？不以物喜 ，不以己悲 。\n居廟堂之高 ，則憂其民 ；處江湖之遠 ，則憂其君 。是進亦憂 ，退亦憂，然則何\n時而樂耶 ？其必曰：「先天下之憂而憂 ，後天下之樂而樂 」歟！噫！微斯人，吾\n誰與歸﹗ \n  鬼頭刀  廖鴻基  \n  漁船鏗鏘的引擎聲 ，響徹黎明港灣 ，破曉晨風迎面吹拂 ，海上一片霧色茫\n茫。 \n  飛魚衝破海面凌空飛起 ，像一隻亮白的飛鳥 ，低空劃過東邊浮出海面的火\n紅朝陽。飛魚飛越了比我歡呼聲更持久的距離 ，在一個漂亮的弧線轉彎後
�麗世界 。薄薄一面\n之隔的海面下 ，那鬼頭刀浮沉的空間 ，是漁人視覺不可及的未知世界 。一個個\n餌鉤沉下水面 ，就像沉下一個個倒懸的問號 ，而答案往往是從零到無窮 ，甚或\n常常連問號也無法收回 。這是在放下餌鉤或撒網當初誰也無法預知的結果 。所\n以漁人必須學會承受不自主的命運 ，學會等待 、落空、失望，或者學會如何承\n受難堪的狂喜 。 \n  海洋那般嚴格的試煉漁人的原始動物性格 ，卻又不斷的誘惑漁人下海的勇\n氣，如潮汐的漲退般 ，漁人宿命的在充滿希望與絕望的空隙間擺盪 。 \n  跟鬼頭刀纏鬥的意志如能量般 累積在我的胸腔 。船筏一次次的在立霧溪海\n口巡弋，也一次次的落空失望 。感覺上鬼頭刀似乎隱藏在海面下的某個角落窺\n視著我們 ，那幽靈般藍色的發亮星點似乎環繞在船筏四周 ，而又在我興奮的跳\n躍起來後消失無蹤 。海上的日子在苦悶的等待中彷彿海水的味道 ，鹹鹹苦苦\n的。偶爾低空貼浪覓食的海鳥 ，常被我誤以為是跳出水面的飛魚而興奮起來 ，\n而灰暗下來 。 \n鬼頭刀是少數兩性表徵明顯的魚類 ，公魚額頭高聳如崖壁 ，就像頭上頂著一把\n劈水的刀斧 ，像公牛隆起的肩或雄獅威風的鬃鬣及吼叫 。母魚全身體型修長圓\n潤，連眼神都帶著幾許溫柔 。「「鬼頭刀」這樣的名稱似乎是來 自公魚的威容 ，漁\n人又稱牠為 「飛魚虎」，從「鬼」、「「刀」、「「虎」這三個字就足以形容鬼頭刀在漁人眼中是如此神秘 、銳利及兇猛 。 \n  同樣時間 、同樣地點 、同樣場景 ，船尾的魚線再度被拉成筆直 。大約在船\n後一百米處中鉤的鬼頭刀不斷的翻躍到空中 ，重重的摔滾在水面上 。我用興奮\n得幾乎顫抖的聲音 ，呼喊海湧伯放慢船速 ，多日來等待的抑鬱都在中魚的瞬間\n明朗起來 。如同長久沉浸的幻影中那般熟練的姿態 ，我雙膝頂住船尾板 ，手中\n緊緊的握住魚線 。心裡充滿自信的告訴自己 ：「「決戰的時刻終於來了 。」一把，\n一把，隨著牠跳躍的節奏有力的收線 ，我嘴裡咕噥著海 湧伯不堪入耳的髒話 。\n在比鬼頭刀更威猛的氣勢下 ，我可以想像背後海湧伯讚許點頭的微笑表情 。 \n  已經收回了大約五十米線 ，牠再度躍出水面 。我竟然看到兩隻鬼頭刀一起\n跳出水面 。大概是眼裡的戰鬥火花模糊了我的視覺 ，用袖口 ...

# %%
def chatting(instruction):
  LAB_prompt = pdf_text + "這是我的國文教材"
  final_prompt = LAB_prompt + instruction
  model = genai.GenerativeModel('gemini-pro')
  response = model.generate_content(final_prompt)
  response.resolve()
  return to_markdown(response.text)

# %%
instruction = "請詳細描述岳陽樓記的意境，其中要有本文即當句之意"

# %%
chatting(instruction)
# Out:
# > **岳陽樓記的意境**
# >
# > * **豁達壯闊：**
# >    - "銜遠山，吞長江，浩浩湯湯，橫無際涯"：描繪出岳陽樓坐擁壯麗山川，氣勢磅礴。
# >
# > * **時空交錯：**
# >    - "朝暉夕陰，氣象萬千"：通過時間的推移，呈現出岳陽樓在不同時刻的風貌，交織出時空交錯的美感。
# >
# > * **憂患與希望：**
# >    - "前人之述備矣。然則北通巫峽，南極瀟湘，遷客騷人，多會於此，覽物之情，得無異乎？"：作者感嘆岳陽樓是文人志士聚會的地方，他們在此抒發憂思，寄託情懷。
# >    - "其必曰：「先天下之憂而憂，後天下之樂而樂」歟！噫！微斯人，吾誰與歸！"：作者借古人之言，表達自己以天下為己任的憂國憂民情懷。
# >
# > * **情景交融：**
# >    - **晴朗時：**"若夫春和景明，波瀾不驚，上下天光，一碧萬頃，沙鷗翔集，錦鱗游泳，岸芷汀蘭，郁郁青青。而或長煙一空，皓月千里，浮光躍金，靜影沉璧，漁歌互答，此樂何極！"描繪出岳陽樓在晴朗時節的幽美景致，人與自然和諧相處的畫面。
# >    - **風雨時：**"至若霪雨霏霏，連月不開，陰風怒號，濁浪排空，日星隱耀，山岳潛形，商旅不行，檣傾楫摧，薄暮冥冥，虎嘯猿啼。"描繪出岳陽樓在風雨時節的淒涼景象，表達出人面對自然災害時的渺小與無助。
# >
# > * **哲理思辨：**
# >    - "不以物喜，不以己悲"：作者認為，賢人君子應當不受外物影響，不為喜悅所迷惑，也不因悲傷而沉淪。
# >    - "居廟堂之高，則憂其民，處江湖之遠，則憂其君"：作者強調，無論在高位還是遠離朝堂，有德之人總會憂國憂民。

# %%
import gradio as gr
import google.generativeai as genai

# 定義 chatting 函數
def chatting(lecture, topic, goal, duration, category):
    # 將使用者輸入的資訊組合成指示
    instruction = f"請幫我設計一堂關於'{lecture}'的課程，主題為'{topic}'，目標是'{goal}'，時長為'{duration}'小時，類別為'{category}'。"
    LAB_prompt = pdf_text + "，這是我的教材，" + instruction + "Use Traditional Chinese" + f"如果你認為主題和{lecture}無關，請直接回答與課程內容無關"
    final_prompt = LAB_prompt + "請換行排版後輸出"
    #print(lecture,topic,goal,duration,category)
    # 假設你已經有一個 GenerativeModel 的物件 model
    model = genai.GenerativeModel('gemini-1.5-pro-latest')
    response = model.generate_content(final_prompt, stream=True)
    response.resolve()
    return remove_mark(response.text)

# 定義 Gradio 介面
demo = gr.Interface(
    chatting,  # 使用 chatting 函數
    [
        gr.Dropdown(
            ["岳陽樓記/范仲淹", "鬼頭刀/廖鴻基","醉翁亭記/歐陽修","裨海紀遊選-北投硫穴記/郁永河","小城連作/鄭愁予","晚由六橋待月記/袁宏道","天才夢/張愛玲","前出師表/諸葛亮","一桿「稱仔」/賴和"], label="Lecture", info="想要哪一課的教案?"),
        gr.Textbox(label="課程主題", lines=3, value=""),
        gr.Textbox(label="教學目標", lines=3, value=""),
        gr.Number(label="課程時長(小時)", value=0),
        gr.Radio(["戶外參訪課程", "室內活動課程", "討論題目"], label="課程類別"),
    ],
    gr.Textbox(label="對話生成結果", lines=10),  # 顯示對話生成結果的文本框
)

if __name__ == "__main__":
    demo.launch()  # 啟動 Gradio 介面
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
能夠讓學生認識海洋保育的重要性及鬼頭刀的習性
鬼頭刀及海洋保育的探討
